# %%
from endstate_rew.analysis import vis_torsions

# %%
vis_torsions(zinc_id = 1, ff = 'openff')
# Out:
# ################################## SYSTEM ZINC06568023 ##################################
# 5 rotatable bonds found.
# ---------- Investigating bond nr 0 ----------
# Dihedrals are computed for bond nr 0
# ---------- Investigating bond nr 1 ----------
# Dihedrals are computed for bond nr 1
# ---------- Investigating bond nr 2 ----------
# Dihedrals are computed for bond nr 2
# ---------- Investigating bond nr 3 ----------
# Dihedrals are computed for bond nr 3
# ---------- Investigating bond nr 4 ----------
# Dihedrals are computed for bond nr 4
